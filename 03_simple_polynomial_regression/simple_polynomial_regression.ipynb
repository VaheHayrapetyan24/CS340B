# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
Y = np.array([2, 3.5, 6, 8, 7, 8.2, 10, 7.9, 6, 5, 4.5, 3])
X = np.array([1, 1.5, 2, 2.5, 3, 3.3, 4, 4.2, 5, 4.8, 5.2, 4.9])

P_degree = 4

# %%
plt.scatter(X, Y)
plt.show()

# %%
powers = np.arange(P_degree)
X_powers = X[:, None]**powers

def linear_regression(l, iter, X, Y):
    theta = np.ones(P_degree)
    for j in range(iter):
        theta = theta + (Y - X_powers.dot(theta)).dot(X_powers)*l/len(Y)
    return theta

# %%
theta = linear_regression(0.0001,600000,X,Y)
Y_predict = X_powers.dot(theta)
print(Y_predict)
# Out:
# [2.29336763 3.88500224 5.52054841 6.99483673 8.10269778 8.50617884
#  8.39846041 8.03880726 4.76648098 5.88588129 3.42431678 5.35320594]

# %%
plt.scatter(X, Y)
plt.scatter(X, Y_predict)
plt.show()

# %%
mean = np.sum(Y) / len(Y)
SST = np.sum((Y - mean)**2)
SSE = np.sum((Y - Y_predict)**2)
print(SST)
print(SSE)
print((SST - SSE)/SST)
# Out:
# 63.8825
# 14.369430142916164
# 0.7750646868404311
