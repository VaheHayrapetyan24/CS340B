# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
csv=pd.read_csv(r"\Users\vaheh\aua\Fall_2024\ML\code\CS340B\02_multiple_linear_regression\Gasprice.txt", header=None)
data = csv.to_numpy()

# %%
Y = np.array(data[:,3])
X = np.concatenate(([np.ones(len(Y))], data[:,0:3].transpose()))

# %%
for i in range(1, len(X)):
    plt.scatter(X[i], Y)
    plt.show()

# %%
def get_cost(X, Y, theta):
    return np.sum((Y - theta.dot(X))**2)/(2 * len(Y))

def linear_regression(l, iter, X, Y):
    cost_history = np.array([])
    theta = np.ones(len(X))
    for j in range(iter):
        theta = theta + l*np.sum((Y - theta.dot(X)) * X, axis=1)/len(Y)
        cost_history = np.append(cost_history, get_cost(X, Y, theta))
    return theta, cost_history

# %%
X_filtered = X[0:3]
theta, cost_history = linear_regression(0.0001,200000,X_filtered,Y)
Y_predict = theta.dot(X_filtered)

# %%
for i in range(1, len(X) - 1):
    plt.scatter(X[i], Y)
    plt.scatter(X[i],Y_predict)
    plt.show()

# %%
plt.plot(cost_history)
plt.show()

# %%
mean = np.sum(Y) / len(Y)
SST = np.sum((Y - mean)**2)
SSE = np.sum((Y - Y_predict)**2)
print(SST)
print(SSE)
print((SST - SSE)/SST)
